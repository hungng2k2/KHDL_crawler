# %%
import pandas as pd

# %%
list_csv = ['bigdataset_01.csv',
            'bigdataset-03-05-2023_18-29.csv',
            'bigdataset-04-05-2023_03-19.csv',
            'bigdataset-04-05-2023_07-11.csv',
            'bigdataset-04-05-2023_07-27.csv',
            'bigdataset-04-05-2023_08-05.csv',
            'bigdataset-04-05-2023_13-09.csv']
columns = ['Hãng xe', 'Dòng xe', 'Năm đăng ký', 'Số Km đã đi', 'Tình trạng', 'Loại xe', 'Dung tích xe', 'Xuất xứ', 'Chính sách bảo hành']

# %%
def merge_csv(list_csv):
    list_dataframe = []
    for csv_file in list_csv:
        list_dataframe.append(pd.read_csv(csv_file))
    unique_dataframe = pd.concat(list_dataframe).drop_duplicates(subset=columns, keep='last')
    return unique_dataframe

# %%
merge_csv(list_csv)
# Out:
#       Hãng xe    Dòng xe Năm đăng ký  Số Km đã đi  Tình trạng       Loại xe
# 9       Honda       Wave        1996        20000  Đã sử dụng         Xe số  \
# 18    Piaggio    Liberty        2014         3000  Đã sử dụng        Tay ga
# 43      Honda        Cub        1992        70000  Đã sử dụng         Xe số
# 49     Yamaha    Exciter        2014        29000  Đã sử dụng         Xe số
# 239       SYM    Elegant        2022         3939  Đã sử dụng         Xe số
# ...       ...        ...         ...          ...         ...           ...
# 3933    Honda     Future        2004       160000  Đã sử dụng         Xe số
# 3934    Honda  Air Blade        2020         7000  Đã sử dụng        Tay ga
# 3935    Honda        Cub        2000        35555  Đã sử dụng         Xe số
# 3936    Honda  Air Blade        2016       460000  Đã sử dụng        Tay ga
# 3937   Yamaha    Exciter        2012         8800  Đã sử dụng  Tay côn/Moto
#
#       Dung tích xe        Xuất xứ Chính sách bảo hành           Giá
# 9     100 - 175 cc  Đang cập nhật       Bảo hành hãng   1.500.000 đ
# 18    100 - 175 cc  Đang cập nhật       Bảo hành hãng   9.500.000 đ
# 43     50 - 100 cc  Đang cập nhật       Bảo hành hãng  12.000.000 đ
# 49    100 - 175 cc  Đang cập nhật       Bảo hành hãng   9.300.000 đ
# 239     Dưới 50 cc  Đang cập nhật       Bảo hành hãng  11.800.000 đ
# ...            ...            ...                 ...           ...
# 3933  100 - 175 cc  Đang cập nhật       Bảo hành hãng  45.000.000 đ
# 3934  100 - 175 cc  Đang cập nhật       Bảo hành hãng  43.800.000 đ
# 3935   50 - 100 cc  Đang cập nhật       Bảo hành hãng   7.850.000 đ
# 3936  100 - 175 cc  Đang cập nhật       Bảo hành hãng  27.000.000 đ
# 3937  100 - 175 cc  Đang cập nhật       Bảo hành hãng  17.500.000 đ
#
# [9293 rows x 10 columns]
