# %%
import pandas as pd

# %%
list_csv = ['bigdataset_01.csv',
            'bigdataset_02.csv',
            'bigdataset-04-05-2023_03-19.csv',
            'bigdataset-04-05-2023_07-11.csv',
            'bigdataset-04-05-2023_07-27.csv',
            'bigdataset-04-05-2023_08-05.csv',
            'bigdataset-04-05-2023_13-09.csv',
            'bigdataset-04-05-2023_16-23.csv']
columns = ['Hãng xe', 'Dòng xe', 'Năm đăng ký', 'Số Km đã đi', 'Tình trạng', 'Loại xe', 'Dung tích xe', 'Xuất xứ', 'Chính sách bảo hành']

# %%
def merge_csv(list_csv):
    list_dataframe = []
    for csv_file in list_csv:
        list_dataframe.append(pd.read_csv(csv_file))
    merged_dataframe = pd.concat(list_dataframe)
    merged_dataframe.reset_index(drop=True, inplace=True)
    merged_dataframe['Năm đăng ký'] = merged_dataframe['Năm đăng ký'].astype(str)
    unique_dataframe = merged_dataframe.drop_duplicates(subset=columns, keep='last')
    return unique_dataframe

# %%
merge_csv(list_csv).to_csv('bigdataset-v1.csv', index=False)

# %%
df = pd.read_csv('bigdataset-v1.csv')
df
# Out:
#        Hãng xe  Dòng xe Năm đăng ký  Số Km đã đi  Tình trạng Loại xe
# 0        Honda     Wave        1996        20000  Đã sử dụng   Xe số  \
# 1      Piaggio  Liberty        2014         3000  Đã sử dụng  Tay ga
# 2        Honda      Cub        1992        70000  Đã sử dụng   Xe số
# 3       Yamaha  Exciter        2014        29000  Đã sử dụng   Xe số
# 4       Yamaha    Nouvo        2011        55555  Đã sử dụng  Tay ga
# ...        ...      ...         ...          ...         ...     ...
# 10036   Yamaha    Nouvo        2015           21  Đã sử dụng  Tay ga
# 10037    Honda       SH        2016        25000  Đã sử dụng  Tay ga
# 10038    Honda      Cub        2019         1000  Đã sử dụng   Xe số
# 10039    Honda     Wave        2010        30000  Đã sử dụng   Xe số
# 10040    Honda      Cub        2013            2  Đã sử dụng   Xe số
#
#        Dung tích xe        Xuất xứ Chính sách bảo hành           Giá
# 0      100 - 175 cc  Đang cập nhật       Bảo hành hãng   1.500.000 đ
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Hãng xe, Dòng xe, Năm đăng ký, Số Km đã đi, Tình trạng, Loại xe, Dung tích xe, Xuất xứ, Chính sách bảo hành, Giá]
# Index: []
