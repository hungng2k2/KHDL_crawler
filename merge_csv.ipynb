# %%
import pandas as pd

# %%
list_csv = ['bigdataset_01.csv',
            'bigdataset-03-05-2023_18-29.csv',
            'bigdataset-04-05-2023_03-19.csv',
            'bigdataset-04-05-2023_07-11.csv',
            'bigdataset-04-05-2023_07-27.csv',
            'bigdataset-04-05-2023_08-05.csv',
            'bigdataset-04-05-2023_13-09.csv',
            'bigdataset-04-05-2023_16-23.csv']
columns = ['Hãng xe', 'Dòng xe', 'Năm đăng ký', 'Số Km đã đi', 'Tình trạng', 'Loại xe', 'Dung tích xe', 'Xuất xứ', 'Chính sách bảo hành']

# %%
def merge_csv(list_csv):
    list_dataframe = []
    for csv_file in list_csv:
        list_dataframe.append(pd.read_csv(csv_file))
    unique_dataframe = pd.concat(list_dataframe).drop_duplicates(subset=columns, keep='last')
    return unique_dataframe

# %%
merge_csv(list_csv).to_csv('bigdataset-v1.csv')

# %%
df = pd.read_csv('bigdataset-v1.csv')
df
# Out:
#        Unnamed: 0  Hãng xe  Dòng xe Năm đăng ký  Số Km đã đi  Tình trạng
# 0               9    Honda     Wave        1996        20000  Đã sử dụng  \
# 1              18  Piaggio  Liberty        2014         3000  Đã sử dụng
# 2              43    Honda      Cub        1992        70000  Đã sử dụng
# 3              49   Yamaha  Exciter        2014        29000  Đã sử dụng
# 4             239      SYM  Elegant        2022         3939  Đã sử dụng
# ...           ...      ...      ...         ...          ...         ...
# 10089        1133   Yamaha    Nouvo        2015           21  Đã sử dụng
# 10090        1134    Honda       SH        2016        25000  Đã sử dụng
# 10091        1135    Honda      Cub        2019         1000  Đã sử dụng
# 10092        1136    Honda     Wave        2010        30000  Đã sử dụng
# 10093        1137    Honda      Cub        2013            2  Đã sử dụng
#
#       Loại xe  Dung tích xe        Xuất xứ Chính sách bảo hành           Giá
# 0       Xe số  100 - 175 cc  Đang cập nhật       Bảo hành hãng   1.500.000 đ
# 1      Tay ga  100 - 175 cc  Đang cập nhật       Bảo hành hãng   9.500.000 đ
# 2       Xe số   50 - 100 cc  Đang cập nhật       Bảo hành hãng  12.000.000 đ
# 3       Xe số  100 - 175 cc  Đang cập nhật       Bảo hành hãng   9.300.000 đ
# 4       Xe số    Dưới 50 cc  Đang cập nhật       Bảo hành hãng  11.800.000 đ
# ...       ...           ...            ...                 ...           ...
# 10089  Tay ga  100 - 175 cc  Đang cập nhật       Bảo hành hãng   7.800.000 đ
# 10090  Tay ga  100 - 175 cc  Đang cập nhật       Bảo hành hãng  52.000.000 đ
# 10091   Xe số  100 - 175 cc  Đang cập nhật       Bảo hành hãng  84.000.000 đ
# 10092   Xe số  100 - 175 cc  Đang cập nhật       Bảo hành hãng   7.800.000 đ
# 10093   Xe số    Dưới 50 cc  Đang cập nhật       Bảo hành hãng   2.100.000 đ
#
# [10094 rows x 11 columns]

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Hãng xe, Dòng xe, Năm đăng ký, Số Km đã đi, Tình trạng, Loại xe, Dung tích xe, Xuất xứ, Chính sách bảo hành, Giá]
# Index: []
