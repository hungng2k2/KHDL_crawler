# %%
import pandas as pd

# %%
list_csv = ['bigdataset-03-05-2023_18-29.csv',
            'bigdataset-04-05-2023_03-19.csv',
            'bigdataset-04-05-2023_07-11.csv',
            'bigdataset-04-05-2023_07-27.csv']
columns = ['Hãng xe', 'Dòng xe', 'Năm đăng ký', 'Số Km đã đi', 'Tình trạng', 'Loại xe', 'Dung tích xe', 'Xuất xứ', 'Chính sách bảo hành']

# %%
def merge_csv(list_csv):
    list_dataframe = []
    for csv_file in list_csv:
        list_dataframe.append(pd.read_csv(csv_file))
    unique_dataframe = pd.concat(list_dataframe).drop_duplicates(subset=columns, keep='last')
    return unique_dataframe

# %%
merge_csv(list_csv)
# Out:
#     Hãng xe    Dòng xe Năm đăng ký  Số Km đã đi  Tình trạng       Loại xe
# 0     Honda  Air Blade        2012            2  Đã sử dụng        Tay ga  \
# 2     Honda       Wave        2012        39000  Đã sử dụng         Xe số
# 3    Yamaha    Exciter        2014        39000  Đã sử dụng  Tay côn/Moto
# 4     Honda  Air Blade        2013        39000  Đã sử dụng        Tay ga
# 6     Honda      Vario        2019        11000  Đã sử dụng        Tay ga
# ..      ...        ...         ...          ...         ...           ...
# 870   Honda      Sonic        2018           10  Đã sử dụng        Tay ga
# 871   Honda         SH        2012        19999  Đã sử dụng        Tay ga
# 872   Honda       Citi        1995       123456  Đã sử dụng         Xe số
# 873   Honda  Air Blade        2015           25  Đã sử dụng        Tay ga
# 874   Honda     Winner        2020         2300  Đã sử dụng  Tay côn/Moto
#
#      Dung tích xe        Xuất xứ Chính sách bảo hành            Giá
# 0    100 - 175 cc  Đang cập nhật       Bảo hành hãng   12.300.000 đ
# 2    100 - 175 cc  Đang cập nhật       Bảo hành hãng    8.800.000 đ
# 3    100 - 175 cc  Đang cập nhật       Bảo hành hãng   12.800.000 đ
# 4    100 - 175 cc  Đang cập nhật       Bảo hành hãng   17.800.000 đ
# 6    100 - 175 cc  Đang cập nhật       Bảo hành hãng   39.000.000 đ
# ..            ...            ...                 ...            ...
# 870  100 - 175 cc  Đang cập nhật       Bảo hành hãng   36.000.000 đ
# 871  100 - 175 cc  Đang cập nhật       Bảo hành hãng  119.666.666 đ
# 872   50 - 100 cc  Đang cập nhật       Bảo hành hãng    8.300.000 đ
# 873  100 - 175 cc  Đang cập nhật       Bảo hành hãng   23.900.000 đ
# 874  100 - 175 cc  Đang cập nhật       Bảo hành hãng   15.800.000 đ
#
# [2949 rows x 10 columns]
